# %%
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 5.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.9 MB 4.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.9 MB 4.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.9 MB 4.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/9.9 MB 4.3 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.9 MB 4.3 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.9 MB 4.3 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.9 MB 4.2 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.9 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 4.5 MB/s  0:00:02
# ...
#
#    ---------------------------------------- 0/2 [narwhals]
# ...

# %%
# !pip install cufflinks
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.2 MB 4.8 MB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 4.5 MB/s  0:00:00
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68561 sha256=54513c350f594d28a70d5248fe07715dec36e98d95a091d471d79ff993edafe8
#   Stored in directory: c:\users\2004r\appdata\local\pip\cache\wheels\c0\d9\70\372130dacf508192607c1a7359c7bf0656b1a3b79f6cf66f7a
# Successfully built cufflinks
# ...
#
# ...
