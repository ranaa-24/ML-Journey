# %%
print("hello mom")
# Out:
# hello mom

# %%
users = {
    'name': 'rana', 
    'age' : 22, 
    2 : 1
}

# %%
print(users)
# Out:
# {'name': 'rana', 'age': 22, 2: 1}

# %%
print(users.keys())
# Out:
# dict_keys(['name', 'age', 2])

# %%
for x in users.values():
    print(x)
# Out:
# rana
# 22
# 1

# %%
ls = [1,2,2,3,4,5,5];

# for i in range(len(ls)):
#     print(i, ls[i])

for i, val in enumerate(ls):
    print(i, val)
# Out:
# 0 1
# 1 2
# 2 2
# 3 3
# 4 4
# 5 5
# 6 5

# %%
ls1 = ["I", "Love", "Her"]
ls2 = [1, 2, 3, 4]

for em, n in zip(ls1, ls2):
    print(em, n)
# Out:
# I 1
# Love 2
# Her 3

# %%
# !pip install ipynb

# %% [markdown]
# ## This is how we import from ipynb

# %%
import ipynb.fs.full.myMath as myMath

# %%
myMath.sub(2, 1)
# Out:
# 1

# %%
file = open('text.txt', 'a');
file.write('and her eyes')
file.close()
